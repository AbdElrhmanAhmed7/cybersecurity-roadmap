# %% [markdown]
# # Day 28 (Secrets module)

# %%
import secrets

# %%
# Generate hexadecimal
secrets.token_hex(16)
# Out:
# '36fc785b3018ffded3d3c88573359d64'

# %%
secrets.randbelow(5)
# Out:
# 4

# %%
secrets.randbits(8)
# Out:
# 129

# %%
secrets.token_bytes(2)
# Out:
# b'\x8b\x8a'

# %%
secrets.token_urlsafe(16)
# Out:
# 'a4VC30UpeNJhza2U4vpVAA'

# %%
lst1 = [secrets.randbits(8) for _ in range(7)]
print(lst)
secrets.choice(lst)
# Out:
# [39, 117, 135, 56, 46, 43, 240]
# 240

# %%
lst2 = [secrets.randbits(8) for _ in range(7)]
secrets.compare_digest(str(lst1[0]), str(lst1[0]))
# Out:
# True

# %%
import secrets
import string


def generate_secure_password(length=12):
    # Combine lowercase, uppercase, digits, and punctuation symbols
    all_characters = string.ascii_letters + string.digits + string.punctuation

    # Securely pick characters from the pool
    password = "".join([secrets.choice(all_characters) for _ in range(length)])
    return password


print("Your new password is:", generate_secure_password(16))
# Out:
# Your new password is: h~[iKL8sAYv%Mx?L

# %%
import secrets

url = 'https://www.web.com/mydomain?brand=mydomain&channelID=P99C101S653N0B2A16D132E0000V147' + \
    secrets.token_urlsafe()
print(url)
# Out:
# https://www.web.com/mydomain?brand=mydomain&channelID=P99C101S653N0B2A16D132E0000V147q7in6WHggDdNCvH7YAVPbmJTRmB1JabcQGj8PB1ORiQ

# %% [markdown]
# # Day 29 (string module)

# %%
import string

# %%
string
# Out:
# '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c'

# %%
password = "hellomother12234@##ABCDAxxS:;s21?><"
hello = "".join(list(filter(lambda x: x.islower(), [ch for ch in password])))
hello
# Out:
# 'hellomotherxxs'
