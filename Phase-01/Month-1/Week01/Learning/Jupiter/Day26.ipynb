# %% [markdown]
# # Day 26 (Automate the boring stuff chapter 12)

# %%
from pathlib import Path
import os
import sys

# %%
print(sys.version_info.major)
print(sys.version_info)
# Out:
# 3
# sys.version_info(major=3, minor=14, micro=3, releaselevel='final', serial=0)

# %%
os.name
# Out:
# 'nt'

# %%
sys.platform
# Out:
# 'win32'

# %%
try:
    import nonexistentModule
except ModuleNotFoundError:
    print("I Know")
# Out:
# I Know

# %%
import argparse
import os

# %%
parser = argparse.ArgumentParser(description="An test for learning")

# %%
print(parser)
# Out:
# ArgumentParser(prog='ipykernel_launcher.py', usage=None, description='An test for learning', formatter_class=<class 'argparse.HelpFormatter'>, conflict_handler='error', add_help=True)

# %%
parser.add_argument('-v', '--verbose', action='store_true',
                    help='Increase output verbosity.')
# Out:
# _StoreTrueAction(option_strings=['-v', '--verbose'], dest='verbose', nargs=0, const=True, default=False, type=None, choices=None, required=False, help='Increase output verbosity.', metavar=None, deprecated=False)

# %%
import re
log_ip = re.search(r"(\d{1,3}\.){3}\d{1,3}", "line").group() or ""
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 import re
# ----> 2 log_ip = re.search(r"(\d{1,3}\.){3}\d{1,3}", "line").group() or ""
#
# AttributeError: 'NoneType' object has no attribute 'group'
